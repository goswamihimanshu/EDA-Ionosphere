# %% [markdown]
# ## import require libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
#load th dataset
df = pd.read_csv('Ionosphere.csv')

# %%
#view top 5 data
df.head()
# Out:
#    V1  V2       V3       V4       V5       V6       V7       V8       V9  \
# 0   1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1   1   0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2   1   0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3   1   0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4   1   0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
#
#        V10  ...        V26      V27      V28      V29      V30      V31  \
# 0  0.03760  ...   -0.51171  0.41078 -0.46168  0.21266 -0.34090  0.42267
# 1 -0.04549  ...   -0.26569 -0.20468 -0.18401 -0.19040 -0.11593 -0.16626
# 2  0.01198  ...   -0.40220  0.58984 -0.22145  0.43100 -0.17365  0.60436
# 3  0.00000  ...    0.90695  0.51613  1.00000  1.00000 -0.20099  0.25682
# 4 -0.16399  ...   -0.65158  0.13290 -0.53206  0.02431 -0.62197 -0.05707
#
#        V32      V33      V34  Class
# 0 -0.54487  0.18641 -0.45300      1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 35 columns):
# V1       351 non-null int64
# V2       351 non-null int64
# V3       351 non-null float64
# V4       351 non-null float64
# V5       351 non-null float64
# V6       351 non-null float64
# V7       351 non-null float64
# V8       351 non-null float64
# V9       351 non-null float64
# V10      351 non-null float64
# V11      351 non-null float64
# V12      351 non-null float64
# V13      351 non-null float64
# V14      351 non-null float64
# V15      351 non-null float64
# V16      351 non-null float64
# V17      351 non-null float64
# V18      351 non-null float64
# V19      351 non-null float64
# V20      351 non-null float64
# V21      351 non-null float64
# V22      351 non-null float64
# V23      351 non-null float64
# V24      351 non-null float64
# V25      351 non-null float64
# V26      351 non-null float64
# V27      351 non-null float64
# ...

# %%
df.describe(include='all').T
# Out:
#        count      mean       std  min       25%      50%       75%  max
# V1     351.0  0.891738  0.311155  0.0  1.000000  1.00000  1.000000  1.0
# V2     351.0  0.000000  0.000000  0.0  0.000000  0.00000  0.000000  0.0
# V3     351.0  0.641342  0.497708 -1.0  0.472135  0.87111  1.000000  1.0
# V4     351.0  0.044372  0.441435 -1.0 -0.064735  0.01631  0.194185  1.0
# V5     351.0  0.601068  0.519862 -1.0  0.412660  0.80920  1.000000  1.0
# V6     351.0  0.115889  0.460810 -1.0 -0.024795  0.02280  0.334655  1.0
# V7     351.0  0.550095  0.492654 -1.0  0.211310  0.72873  0.969240  1.0
# V8     351.0  0.119360  0.520750 -1.0 -0.054840  0.01471  0.445675  1.0
# V9     351.0  0.511848  0.507066 -1.0  0.087110  0.68421  0.953240  1.0
# V10    351.0  0.181345  0.483851 -1.0 -0.048075  0.01829  0.534195  1.0
# V11    351.0  0.476183  0.563496 -1.0  0.021120  0.66798  0.957895  1.0
# V12    351.0  0.155040  0.494817 -1.0 -0.065265  0.02825  0.482375  1.0
# ...

# %%
df.shape
# Out:
# (351, 35)

# %%
#cheking null values
df.isnull().sum()
# Out:
# V1       0
# V2       0
# V3       0
# V4       0
# V5       0
# V6       0
# V7       0
# V8       0
# V9       0
# V10      0
# V11      0
# V12      0
# V13      0
# V14      0
# V15      0
# V16      0
# V17      0
# V18      0
# V19      0
# V20      0
# V21      0
# V22      0
# V23      0
# V24      0
# V25      0
# V26      0
# V27      0
# V28      0
# V29      0
# V30      0
# V31      0
# V32      0
# V33      0
# V34      0
# Class    0
# dtype: int64

# %%
#cheking any special charater in avaliable in anly columns
for i in df:
    print(i)
    print(df[i].unique())
# Out:
# V1
# [1 0]
# V2
# [0]
# V3
# [ 0.99539  1.       0.02337  0.97588  0.       0.96355 -0.01864  0.50932
#   0.99645  0.67065  0.96071 -1.       0.88208  0.71253  0.66161  0.91241
#   0.90932 -0.64286  0.99025  0.94598  0.98166  0.84134 -0.67935  0.95659
#   0.08333  0.17188  0.01667  0.63816  0.84783  0.96087  0.69444  0.92277
#   0.68198  0.74852  0.39179  0.67547  0.72727  0.57647  0.41932  0.88305
#   0.84557  0.7087  -0.5418   0.29202  0.79157  0.90116  0.97714  0.74084
#   0.95704  0.28409  0.9449   0.99449  0.10135  0.65909  0.86284  0.42
#   0.91353  0.21429  0.98182  0.39286  0.86889  0.43636  0.7381   0.4375
#   0.95217  0.5984   0.95882  0.96933  0.64122  0.34694  0.89706  0.26667
#  -0.26667  0.94531  0.95202  0.31034  0.62745  0.25    -0.65625  0.85271
#   0.90374 -0.205    0.6      0.05866  0.94653  0.0546   0.72414  0.03852
#   0.4709   0.08696  0.94333  0.01975  0.85736  0.85209  0.44444  0.62121
#   0.91667  0.1859   0.92247  0.84177  0.64947  0.93669  0.36876  0.79847
# ...

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Univariate Analysis

# %%
#histogram for all the columns
df.hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002709FB6D128>,
# ...
#       dtype=object)

# %%
#box plot all the columns
for num_var in df:
    plt.figure(figsize=(10,5))
    sns.boxplot(x=df[num_var])

# %%
#count how many 0 and 1 in V1
sns.countplot(df['V1'])

# %%
#count how many 0 and 1 in Class
sns.countplot(df['Class'])

# %% [markdown]
# ## Bivariate Analysis

# %%
for feature in df:
    sns.regplot(y = feature,x = df['Class'],data =df )
    plt.xlabel('Class')
    #plt.title(feature)
    plt.xticks(rotation=90)

    plt.show()

# %%
df.corr().T
# Out:
#              V1  V2        V3        V4        V5        V6        V7  \
# V1     1.000000 NaN  0.302034 -0.006529  0.156152  0.127606  0.221867
# V2          NaN NaN       NaN       NaN       NaN       NaN       NaN
# V3     0.302034 NaN  1.000000  0.143365  0.476587  0.025768  0.440254
# V4    -0.006529 NaN  0.143365  1.000000  0.001152 -0.190308 -0.054030
# V5     0.156152 NaN  0.476587  0.001152  1.000000  0.038323  0.597075
# V6     0.127606 NaN  0.025768 -0.190308  0.038323  1.000000 -0.010227
# V7     0.221867 NaN  0.440254 -0.054030  0.597075 -0.010227  1.000000
# V8     0.027079 NaN  0.008717  0.255003 -0.029794  0.274747 -0.150424
# V9     0.189242 NaN  0.471614 -0.302317  0.450454 -0.120712  0.461889
# V10   -0.051883 NaN  0.047916  0.207697 -0.034236  0.200080 -0.090268
# V11    0.034138 NaN  0.325016 -0.190090  0.449829 -0.291447  0.412876
# V12    0.072216 NaN  0.169981  0.315877  0.042896  0.163933 -0.020395
# ...

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ## Creating Independent and Dependent Variables

# %%
# Independent variables
X = df.drop(columns = ['Class'],axis = 1)
X.head()
# Out:
#    V1  V2       V3       V4       V5       V6       V7       V8       V9  \
# 0   1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1   1   0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2   1   0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3   1   0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4   1   0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
#
#        V10   ...         V25      V26      V27      V28      V29      V30  \
# 0  0.03760   ...     0.56811 -0.51171  0.41078 -0.46168  0.21266 -0.34090
# 1 -0.04549   ...    -0.20332 -0.26569 -0.20468 -0.18401 -0.19040 -0.11593
# 2  0.01198   ...     0.57528 -0.40220  0.58984 -0.22145  0.43100 -0.17365
# 3  0.00000   ...     1.00000  0.90695  0.51613  1.00000  1.00000 -0.20099
# 4 -0.16399   ...     0.03286 -0.65158  0.13290 -0.53206  0.02431 -0.62197
#
#        V31      V32      V33      V34
# 0  0.42267 -0.54487  0.18641 -0.45300
# ...

# %%
# Dependent variable
y = df['Class']
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Class, dtype: int64

# %% [markdown]
# ## Spliting

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (235, 34) (116, 34) (235,) (116,)

# %% [markdown]
# ### Scaling the numerical features:

# %%
# Scaling of data
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
model_log = LogisticRegression()

# %%
model_log.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred_log = model_log.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
cm = confusion_matrix(y_test,y_pred_log)
plt.figure(figsize = (5,3))

sns.heatmap(cm,annot = True,fmt = '0.2f',xticklabels=['class-0','class-1'],
           yticklabels=['class-0','class-1'],cbar=False)
plt.xlabel('Predicted Values')
plt.ylabel('True Values')
# Out:
# Text(24.0, 0.5, 'True Values')

# %%
cr = classification_report(y_test,y_pred_log)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.60      0.75        45
#            1       0.80      1.00      0.89        71
#
#    micro avg       0.84      0.84      0.84       116
#    macro avg       0.90      0.80      0.82       116
# weighted avg       0.88      0.84      0.83       116

# %%
log_model_score = model_log.score(X_test,y_test)
print(log_model_score)
# Out:
# 0.8448275862068966

# %% [markdown]
# ## Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model_tree = DecisionTreeClassifier(criterion = 'gini', max_depth = None)

# %%
model_tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
y_pred_tree = model_tree.predict(X_test)

# %%
cm = confusion_matrix(y_test,y_pred_tree)
plt.figure(figsize = (5,3))

sns.heatmap(cm,annot = True,fmt = '0.2f',xticklabels=['class-0','class-1'],
           yticklabels=['class-0','class-1'],cbar=False)
plt.xlabel('Predicted Values')
plt.ylabel('True Values')
# Out:
# Text(24.0, 0.5, 'True Values')

# %%
cr = classification_report(y_test,y_pred_tree)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.73      0.80        45
#            1       0.85      0.93      0.89        71
#
#    micro avg       0.85      0.85      0.85       116
#    macro avg       0.86      0.83      0.84       116
# weighted avg       0.85      0.85      0.85       116

# %%
desicion_tree_model_score = model_tree.score(X_test,y_test)
print(desicion_tree_model_score)
# Out:
# 0.853448275862069

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_rf = RandomForestClassifier(n_estimators=20, criterion='gini',
                              max_features = 0.2)

# %%
model_rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features=0.2, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=20, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_pred_rf = model_rf.predict(X_test)

# %%
cm = confusion_matrix(y_test,y_pred_rf)
plt.figure(figsize = (5,3))

sns.heatmap(cm,annot = True,fmt = '0.2f',xticklabels=['class-0','class-1'],
           yticklabels=['class-0','class-1'],cbar=False)
plt.xlabel('Predicted Values')
plt.ylabel('True Values')
# Out:
# Text(24.0, 0.5, 'True Values')

# %%
cr = classification_report(y_test,y_pred_rf)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.87      0.92        45
#            1       0.92      0.99      0.95        71
#
#    micro avg       0.94      0.94      0.94       116
#    macro avg       0.95      0.93      0.94       116
# weighted avg       0.94      0.94      0.94       116

# %%
random_model_score = model_rf.score(X_test,y_test)
print(random_model_score)
# Out:
# 0.9396551724137931

# %% [markdown]
# ## K-Nearest Neighbour Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model_knn = KNeighborsClassifier()

# %%
model_knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
y_pred_knn = KNN.predict(X_test)

# %%
cm = confusion_matrix(y_test,y_pred_knn)
plt.figure(figsize = (5,3))

sns.heatmap(cm,annot = True,fmt = '0.2f',xticklabels=['class-0','class-1'],
           yticklabels=['class-0','class-1'],cbar=False)
plt.xlabel('Predicted Values')
plt.ylabel('True Values')
# Out:
# Text(24.0, 0.5, 'True Values')

# %%
cr = classification_report(y_test,y_pred_knn)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.51      0.68        45
#            1       0.76      1.00      0.87        71
#
#    micro avg       0.81      0.81      0.81       116
#    macro avg       0.88      0.76      0.77       116
# weighted avg       0.86      0.81      0.79       116

# %%
knn_model_score =model_knn.score(X_test,y_test)
print(knn_model_score)
# Out:
# 0.8103448275862069

# %% [markdown]
# ## Support Vector Classifier

# %%
from sklearn.svm import SVC

# %%
model = SVC(C = 1)
model_svm = model.fit(X_train,y_train)

# %%
y_pred_svm = model_svm.predict(X_test)

# %%
cm = confusion_matrix(y_test,y_pred_svm)
plt.figure(figsize = (5,3))

sns.heatmap(cm,annot = True,fmt = '0.2f',xticklabels=['class-0','class-1'],
           yticklabels=['class-0','class-1'],cbar=False)
plt.xlabel('Predicted Values')
plt.ylabel('True Values')
# Out:
# Text(24.0, 0.5, 'True Values')

# %%
cr = classification_report(y_test,y_pred_svm)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.58      0.73        45
#            1       0.79      1.00      0.88        71
#
#    micro avg       0.84      0.84      0.84       116
#    macro avg       0.89      0.79      0.81       116
# weighted avg       0.87      0.84      0.82       116

# %%
svm_model_score = model_svm.score(X_test,y_test)
print(svm_model_score)
# Out:
# 0.8362068965517241

# %% [markdown]
# ## Naive Base Classifier

# %%
from sklearn.naive_bayes import GaussianNB

# %%
NavBas = GaussianNB()

# %%
model_NB = NavBas.fit(X_train,y_train)

# %%
y_pred_NB = model_NB.predict(X_test)

# %%
cm = confusion_matrix(y_test,y_pred_NB)
plt.figure(figsize = (5,3))

sns.heatmap(cm,annot = True,fmt = '0.2f',xticklabels=['class-0','class-1'],
           yticklabels=['class-0','class-1'],cbar=False)
plt.xlabel('Predicted Values')
plt.ylabel('True Values')
# Out:
# Text(24.0, 0.5, 'True Values')

# %%
cr = classification_report(y_test,y_pred_NB)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.73      0.84        45
#            1       0.85      0.99      0.92        71
#
#    micro avg       0.89      0.89      0.89       116
#    macro avg       0.91      0.86      0.88       116
# weighted avg       0.90      0.89      0.88       116

# %%
naive_model_score = model_NB.score(X_test,y_test)
print(naive_model_score)
# Out:
# 0.8879310344827587

# %% [markdown]
# ## All the model accuracy

# %%
log_model_score
# Out:
# 0.8448275862068966

# %%
desicion_tree_model_score
# Out:
# 0.853448275862069

# %%
random_model_score
# Out:
# 0.9396551724137931

# %%
knn_model_score
# Out:
# 0.8103448275862069

# %%
svm_model_score
# Out:
# 0.8362068965517241

# %%
naive_model_score
# Out:
# 0.8879310344827587

# %% [markdown]
# ### Conclusion

# %% [markdown]
# ### Random forest model is best accuracy among them
